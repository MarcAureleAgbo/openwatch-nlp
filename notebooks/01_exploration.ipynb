# %% [markdown]
# # OpenWatch NLP - Exploration
#
# This notebook is intentionally lightweight. The production logic lives in `src/` so the project remains reproducible from scripts.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('../data/raw/synthetic_public_signals.csv')
dataset = pd.read_csv(data_path)
dataset.head()

# %%
dataset['label'].value_counts()

# %%
dataset.groupby(['label', 'source_type']).size().unstack(fill_value=0)
